# %%
from IPython.display import HTML

# Define HTML and CSS to hide code and output
hide_code_html = """
    <script>
        function code_toggle() {
            if (code_shown){
                $('div.input').hide('500');
                $('#toggleButton').val('Show Code')
            } else {
                $('div.input').show('500');
                $('#toggleButton').val('Hide Code')
            }
            code_shown = !code_shown
        }

        $( document ).ready(function(){
            code_shown=false;
            $('div.input').hide()
        });
    </script>
    <form action="javascript:code_toggle()">
        <input type="submit" id="toggleButton" value="Show Code">
    </form>
"""

# Display the HTML to hide code
display(HTML(hide_code_html))
# Out:
#     <script>
#         function code_toggle() {
#             if (code_shown){
#                 $('div.input').hide('500');
#                 $('#toggleButton').val('Show Code')
#             } else {
#                 $('div.input').show('500');
#                 $('#toggleButton').val('Hide Code')
#             }
#             code_shown = !code_shown
#         }
#
#         $( document ).ready(function(){
#             code_shown=false;
#             $('div.input').hide()
#         });
#     </script>
#     <form action="javascript:code_toggle()">
#         <input type="submit" id="toggleButton" value="Show Code">
#     </form>

# %%
from IPython.display import Image, display
# Specify the path to your image
image_path = r'C:\Users\Ken\Desktop\My Learning\Portfolio Projects\1Million songs\assets\img\project\myprojects\1MillionSongz.jpg'

# Display the image
display(Image(filename=image_path, width=300, height=100))

# %% [markdown]
# # 1 Million Songs Recomendation system

# %%
from IPython.display import Image, display

# Specify the path to your image
image_path = r'C:\Users\Ken\Desktop\My Learning\Portfolio Projects\1Million songs\assets\img\project\myprojects\music landscape7.jpeg'

# Display the image
display(Image(filename=image_path, width=500, height=20))

# %%
# !pip install seaborn
# !pip install wordcloud
# !pip install dash pandas
# !pip install ipywidgets
# !pip install --upgrade wordcloud
# !pip install matplotlib numpy pillow
# Out:
# Requirement already satisfied: seaborn in c:\users\ken\anaconda3\lib\site-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\users\ken\anaconda3\lib\site-packages (from seaborn) (1.26.2)
# Requirement already satisfied: pandas>=0.25 in c:\users\ken\anaconda3\lib\site-packages (from seaborn) (2.1.4)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\ken\anaconda3\lib\site-packages (from seaborn) (3.7.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\ken\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\ken\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (5.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ken\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\ken\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\ken\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (8.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ken\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ken\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.25.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ken\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ken\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ken\anaconda3\lib\site-packages (from pandas>=0.25->seaborn) (2022.7)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\ken\anaconda3\lib\site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\ken\anaconda3\lib\site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.1->seaborn) (3.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\ken\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# WARNING: Ignoring invalid distribution -illow (c:\users\ken\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\ken\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\ken\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\ken\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\ken\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\ken\anaconda3\lib\site-packages)
# Requirement already satisfied: wordcloud in c:\users\ken\anaconda3\lib\site-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\ken\anaconda3\lib\site-packages (from wordcloud) (1.26.2)
# Requirement already satisfied: pillow in c:\users\ken\anaconda3\lib\site-packages (from wordcloud) (8.2.0)
# Requirement already satisfied: matplotlib in c:\users\ken\anaconda3\lib\site-packages (from wordcloud) (3.7.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ken\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\ken\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ken\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ken\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\ken\anaconda3\lib\site-packages (from matplotlib->wordcloud) (23.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ken\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\ken\anaconda3\lib\site-packages (from matplotlib->wordcloud) (5.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ken\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\ken\anaconda3\lib\site-packages (from importlib-resources>=3.2.0->matplotlib->wordcloud) (3.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\ken\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# WARNING: Ignoring invalid distribution -illow (c:\users\ken\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\ken\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\ken\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\ken\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\ken\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\ken\anaconda3\lib\site-packages)
# Requirement already satisfied: dash in c:\users\ken\anaconda3\lib\site-packages (2.14.2)
# Requirement already satisfied: pandas in c:\users\ken\anaconda3\lib\site-packages (2.1.4)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\ken\anaconda3\lib\site-packages (from dash) (2.0.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\ken\anaconda3\lib\site-packages (from dash) (4.5.0)
# Requirement already satisfied: requests in c:\users\ken\anaconda3\lib\site-packages (from dash) (2.25.1)
# Requirement already satisfied: ansi2html in c:\users\ken\anaconda3\lib\site-packages (from dash) (1.9.1)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\ken\anaconda3\lib\site-packages (from dash) (5.9.0)
# Requirement already satisfied: importlib-metadata in c:\users\ken\anaconda3\lib\site-packages (from dash) (6.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\ken\anaconda3\lib\site-packages (from dash) (5.0.0)
# Requirement already satisfied: nest-asyncio in c:\users\ken\anaconda3\lib\site-packages (from dash) (1.5.6)
# Requirement already satisfied: retrying in c:\users\ken\anaconda3\lib\site-packages (from dash) (1.3.4)
# Requirement already satisfied: Werkzeug<3.1 in c:\users\ken\anaconda3\lib\site-packages (from dash) (2.0.3)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in c:\users\ken\anaconda3\lib\site-packages (from dash) (1.1.2)
# Requirement already satisfied: setuptools in c:\users\ken\anaconda3\lib\site-packages (from dash) (65.6.3)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\ken\anaconda3\lib\site-packages (from dash) (2.0.0)
# Requirement already satisfied: numpy<2,>=1.22.4 in c:\users\ken\anaconda3\lib\site-packages (from pandas) (1.26.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ken\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ken\anaconda3\lib\site-packages (from pandas) (2022.7)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\ken\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: click>=5.1 in c:\users\ken\anaconda3\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (8.0.4)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\ken\anaconda3\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (2.0.1)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\ken\anaconda3\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (2.11.3)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\ken\anaconda3\lib\site-packages (from plotly>=5.0.0->dash) (8.2.3)
# Requirement already satisfied: six>=1.5 in c:\users\ken\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\ken\anaconda3\lib\site-packages (from importlib-metadata->dash) (3.11.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ken\anaconda3\lib\site-packages (from requests->dash) (2023.5.7)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\ken\anaconda3\lib\site-packages (from requests->dash) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ken\anaconda3\lib\site-packages (from requests->dash) (1.26.14)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\ken\anaconda3\lib\site-packages (from requests->dash) (4.0.0)
# Requirement already satisfied: colorama in c:\users\ken\anaconda3\lib\site-packages (from click>=5.1->Flask<3.1,>=1.0.4->dash) (0.4.6)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\ken\anaconda3\lib\site-packages (from Jinja2>=2.10.1->Flask<3.1,>=1.0.4->dash) (1.1.1)
# WARNING: Ignoring invalid distribution -illow (c:\users\ken\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\ken\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\ken\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\ken\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\ken\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\ken\anaconda3\lib\site-packages)
# Requirement already satisfied: ipywidgets in c:\users\ken\anaconda3\lib\site-packages (7.6.5)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\ken\anaconda3\lib\site-packages (from ipywidgets) (8.10.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\ken\anaconda3\lib\site-packages (from ipywidgets) (6.19.2)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\ken\anaconda3\lib\site-packages (from ipywidgets) (5.7.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\ken\anaconda3\lib\site-packages (from ipywidgets) (1.0.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\ken\anaconda3\lib\site-packages (from ipywidgets) (3.5.2)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\ken\anaconda3\lib\site-packages (from ipywidgets) (5.7.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\ken\anaconda3\lib\site-packages (from ipywidgets) (0.2.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\ken\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.2)
# Requirement already satisfied: nest-asyncio in c:\users\ken\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.6)
# Requirement already satisfied: packaging in c:\users\ken\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (23.0)
# Requirement already satisfied: psutil in c:\users\ken\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (5.9.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\ken\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (6.1.12)
# Requirement already satisfied: tornado>=6.1 in c:\users\ken\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (6.2)
# Requirement already satisfied: pyzmq>=17 in c:\users\ken\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (23.2.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\ken\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.6)
# Requirement already satisfied: debugpy>=1.0 in c:\users\ken\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.1)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\ken\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets) (2.17.2)
# Requirement already satisfied: stack-data in c:\users\ken\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.2.0)
# Requirement already satisfied: pickleshare in c:\users\ken\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in c:\users\ken\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.18.1)
# Requirement already satisfied: decorator in c:\users\ken\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets) (5.1.1)
# Requirement already satisfied: backcall in c:\users\ken\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.2.0)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.30 in c:\users\ken\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets) (3.0.36)
# Requirement already satisfied: colorama in c:\users\ken\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.4.6)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\ken\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets) (4.17.3)
# Requirement already satisfied: jupyter-core in c:\users\ken\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets) (5.2.0)
# Requirement already satisfied: fastjsonschema in c:\users\ken\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets) (2.16.2)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\ken\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets) (6.4.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\ken\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets) (0.8.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\ken\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\ken\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets) (0.18.0)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\ken\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (2.8.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\ken\anaconda3\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets) (305.1)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\ken\anaconda3\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets) (2.5.2)
# Requirement already satisfied: argon2-cffi in c:\users\ken\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (21.3.0)
# Requirement already satisfied: jinja2 in c:\users\ken\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.11.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\ken\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.17.1)
# Requirement already satisfied: prometheus-client in c:\users\ken\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.14.1)
# Requirement already satisfied: Send2Trash>=1.5.0 in c:\users\ken\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.8.0)
# Requirement already satisfied: nbconvert in c:\users\ken\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (6.1.0)
# Requirement already satisfied: wcwidth in c:\users\ken\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.30->ipython>=4.0.0->ipywidgets) (0.2.5)
# Requirement already satisfied: pure-eval in c:\users\ken\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (0.2.2)
# Requirement already satisfied: asttokens in c:\users\ken\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (2.0.5)
# Requirement already satisfied: executing in c:\users\ken\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (0.8.3)
# Requirement already satisfied: six>=1.5 in c:\users\ken\anaconda3\lib\site-packages (from python-dateutil>=2.1->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (1.16.0)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\ken\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.0.10)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\ken\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (21.2.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\ken\anaconda3\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.1.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\ken\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.8.4)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\ken\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.4)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\ken\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.13)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\ken\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.5.0)
# Requirement already satisfied: defusedxml in c:\users\ken\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.7.1)
# Requirement already satisfied: testpath in c:\users\ken\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.6.0)
# Requirement already satisfied: jupyterlab-pygments in c:\users\ken\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.1.2)
# Requirement already satisfied: bleach in c:\users\ken\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (4.1.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\ken\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.15.1)
# Requirement already satisfied: webencodings in c:\users\ken\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.1)
# Requirement already satisfied: pycparser in c:\users\ken\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.21)
# WARNING: Ignoring invalid distribution -illow (c:\users\ken\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\ken\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\ken\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\ken\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\ken\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\ken\anaconda3\lib\site-packages)
# Requirement already satisfied: wordcloud in c:\users\ken\anaconda3\lib\site-packages (1.9.3)
# Requirement already satisfied: matplotlib in c:\users\ken\anaconda3\lib\site-packages (from wordcloud) (3.7.1)
# Requirement already satisfied: pillow in c:\users\ken\anaconda3\lib\site-packages (from wordcloud) (8.2.0)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\ken\anaconda3\lib\site-packages (from wordcloud) (1.26.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\ken\anaconda3\lib\site-packages (from matplotlib->wordcloud) (23.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\ken\anaconda3\lib\site-packages (from matplotlib->wordcloud) (5.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\ken\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ken\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ken\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ken\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ken\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ken\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\ken\anaconda3\lib\site-packages (from importlib-resources>=3.2.0->matplotlib->wordcloud) (3.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\ken\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# WARNING: Ignoring invalid distribution -illow (c:\users\ken\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\ken\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\ken\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\ken\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\ken\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\ken\anaconda3\lib\site-packages)
# Requirement already satisfied: matplotlib in c:\users\ken\anaconda3\lib\site-packages (3.7.1)
# Requirement already satisfied: numpy in c:\users\ken\anaconda3\lib\site-packages (1.26.2)
# Requirement already satisfied: pillow in c:\users\ken\anaconda3\lib\site-packages (8.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ken\anaconda3\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ken\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ken\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\ken\anaconda3\lib\site-packages (from matplotlib) (5.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\ken\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ken\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\ken\anaconda3\lib\site-packages (from matplotlib) (23.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ken\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\ken\anaconda3\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\ken\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# WARNING: Ignoring invalid distribution -illow (c:\users\ken\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\ken\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\ken\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\ken\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\ken\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\ken\anaconda3\lib\site-packages)

# %% [markdown]
# ## Content-Based Recomendation system

# %% [markdown]
# The goal of this project is to develop a music recommendation system using python and deploy it on stremlit
# By the end of this project we will do:-
#
# 1.Comprehensive Data Exploration (EDA)
#
# 2.Preprocessing
#
# 3.Feature Engineering
#
# 4.Model Development
#
# 5.Integration of Features
#
# 6.Optimized Model
#
# 7.Deployment on Streamlit

# %% [markdown]
# ### Files Upload
# Our data comprises of 2 Spotify csv files of:
#
# 1. Different songs and their differen characteristics  including textual features and audio features (df)
#
# 2. Different user interaction with different songs (df1)

# %%
import pandas as pd
import pickle
# Assuming your file is named 'your_file.csv'
df = pd.read_csv(r'C:\Users\Ken\Desktop\My Learning\Portfolio Projects\1Million songs\Files\Music Info.csv')
df1=pd.read_csv(r'C:\Users\Ken\Desktop\My Learning\Portfolio Projects\1Million songs\Files\User Listening History.csv')

# %%
print("Data Overview: Head")
df.head()
# Out:
# Data Overview: Head
#              track_id             name           artist  \
# 0  TRIOREW128F424EAF0   Mr. Brightside      The Killers
# 1  TRRIVDJ128F429B0E8       Wonderwall            Oasis
# 2  TROUVHL128F426C441  Come as You Are          Nirvana
# 3  TRUEIND128F93038C4      Take Me Out  Franz Ferdinand
# 4  TRLNZBD128F935E4D8            Creep        Radiohead
#
#                                  spotify_preview_url              spotify_id  \
# 0  https://p.scdn.co/mp3-preview/4d26180e6961fd46...  09ZQ5TmUG8TSL56n0knqrj
# 1  https://p.scdn.co/mp3-preview/d012e536916c927b...  06UfBBDISthj1ZJAtX4xjj
# 2  https://p.scdn.co/mp3-preview/a1c11bb1cb231031...  0keNu0t0tqsWtExGM3nT1D
# 3  https://p.scdn.co/mp3-preview/399c401370438be4...  0ancVQ9wEcHVd0RrGICTE4
# 4  https://p.scdn.co/mp3-preview/e7eb60e9466bc3a2...  01QoK9DA7VTeTSE3MNzp4I
#
#                                                 tags genre  year  duration_ms  \
# 0  rock, alternative, indie, alternative_rock, in...   NaN  2004       222200
# 1  rock, alternative, indie, pop, alternative_roc...   NaN  2006       258613
# 2   rock, alternative, alternative_rock, 90s, grunge   RnB  1991       218920
# 3  rock, alternative, indie, alternative_rock, in...   NaN  2004       237026
# 4  rock, alternative, indie, alternative_rock, in...   RnB  2008       238640
#
#    danceability  ...  key  loudness  mode  speechiness  acousticness  \
# 0         0.355  ...    1    -4.360     1       0.0746      0.001190
# 1         0.409  ...    2    -4.373     1       0.0336      0.000807
# 2         0.508  ...    4    -5.783     0       0.0400      0.000175
# 3         0.279  ...    9    -8.851     1       0.0371      0.000389
# 4         0.515  ...    7    -9.935     1       0.0369      0.010200
#
#    instrumentalness  liveness  valence    tempo  time_signature
# 0          0.000000    0.0971    0.240  148.114               4
# 1          0.000000    0.2070    0.651  174.426               4
# 2          0.000459    0.0878    0.543  120.012               4
# 3          0.000655    0.1330    0.490  104.560               4
# 4          0.000141    0.1290    0.104   91.841               4
#
# [5 rows x 21 columns]

# %%
print("Data Overview: Tail")
df.tail()
# Out:
# Data Overview: Tail
#                  track_id                name                 artist  \
# 50678  TRQYCFV128F9322F50       Ryusei Rocket            アンティック-珈琲店-
# 50679  TRHQCSH128F42724B7  Colors Of The Wind                ACIDMAN
# 50680  TRZRODK128F92D68D7      The Revelation               coldrain
# 50681  TRGLMEM128F9322F63   Koi no Dependence            アンティック-珈琲店-
# 50682  TRIPFKO128F42383FE         Hide & Seek  9mm Parabellum Bullet
#
#                                      spotify_preview_url  \
# 50678  https://p.scdn.co/mp3-preview/d2668a5a3e0b1fda...
# 50679  https://p.scdn.co/mp3-preview/8e22a7052ef3ecf7...
# 50680  https://p.scdn.co/mp3-preview/4b51a813f67e3853...
# 50681  https://p.scdn.co/mp3-preview/5a61e031df174666...
# 50682  https://p.scdn.co/mp3-preview/91778ba6f91086f4...
#
#                    spotify_id                                     tags  \
# 50678  0tt1RdeJX1RyuU4hMEZ19T                                      NaN
# 50679  3wkdfXGf5JYErW4b35zP2h  rock, alternative_rock, japanese, cover
# 50680  1gXMORZRGA40PE9rDE9cja          metal, metalcore, post_hardcore
# 50681  1dxMDGvIYHFYgRvmw1uMHG                                      NaN
# 50682  3LW19oCCXxiqRcnlcQqPr3                           rock, japanese
#
#             genre  year  duration_ms  danceability  ...  key  loudness  mode  \
# 50678         NaN  2008       273440         0.438  ...    6    -3.062     0
# 50679         NaN  2004       275133         0.351  ...    0    -6.811     1
# 50680         NaN  2014       254826         0.434  ...   10    -3.092     0
# 50681         NaN  2008       243293         0.513  ...    4    -3.914     0
# 50682  Electronic  2008       131960         0.190  ...    8    -4.144     1
#
#        speechiness  acousticness  instrumentalness  liveness  valence  \
# 50678        0.165      0.003120          0.000000    0.1300    0.421
# 50679        0.120      0.000940          0.000049    0.1920    0.450
# 50680        0.268      0.000108          0.001410    0.1630    0.282
# 50681        0.053      0.000715          0.001350    0.0571    0.618
# 50682        0.131      0.000033          0.051100    0.2030    0.138
#
#          tempo  time_signature
# 50678  166.956               4
# 50679  200.350               4
# 50680  158.025               4
# 50681  109.923               4
# 50682  136.475               4
#
# [5 rows x 21 columns]

# %%
print("\nData Types:")
print(df.dtypes)
# Out:
# Data Types:
# track_id                object
# name                    object
# artist                  object
# spotify_preview_url     object
# spotify_id              object
# tags                    object
# genre                   object
# year                     int64
# duration_ms              int64
# danceability           float64
# energy                 float64
# key                      int64
# loudness               float64
# mode                     int64
# speechiness            float64
# acousticness           float64
# instrumentalness       float64
# liveness               float64
# valence                float64
# tempo                  float64
# time_signature           int64
# dtype: object

# %%
print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# track_id                   0
# name                       0
# artist                     0
# spotify_preview_url        0
# spotify_id                 0
# tags                    1127
# genre                  28335
# year                       0
# duration_ms                0
# danceability               0
# energy                     0
# key                        0
# loudness                   0
# mode                       0
# speechiness                0
# acousticness               0
# instrumentalness           0
# liveness                   0
# valence                    0
# tempo                      0
# time_signature             0
# dtype: int64

# %%
print("\nUnique Values:")
print(df.nunique())
# Out:
# Unique Values:
# track_id               50683
# name                   50683
# artist                  8317
# spotify_preview_url    50620
# spotify_id             50674
# tags                   20057
# genre                     15
# year                      75
# duration_ms            24202
# danceability            1086
# energy                  1600
# key                       12
# loudness               15316
# mode                       2
# speechiness             1300
# acousticness            5193
# instrumentalness        5245
# liveness                1696
# valence                 1649
# tempo                  36157
# time_signature             5
# dtype: int64

# %%
print("\nDescriptive Statistics:")
print(df.describe())
# Out:
# Descriptive Statistics:
#                year   duration_ms  danceability        energy           key  \
# count  50683.000000  5.068300e+04  50683.000000  50683.000000  50683.000000
# mean    2004.017323  2.511551e+05      0.493537      0.686486      5.312748
# std        8.860172  1.075860e+05      0.178838      0.251808      3.568078
# min     1900.000000  1.439000e+03      0.000000      0.000000      0.000000
# 25%     2001.000000  1.927330e+05      0.364000      0.514000      2.000000
# 50%     2006.000000  2.349330e+05      0.497000      0.744000      5.000000
# 75%     2009.000000  2.881930e+05      0.621000      0.905000      9.000000
# max     2022.000000  3.816373e+06      0.986000      1.000000     11.000000
#
#            loudness          mode   speechiness  acousticness  \
# count  50683.000000  50683.000000  50683.000000  50683.000000
# mean      -8.291204      0.631060      0.076023      0.213808
# std        4.548365      0.482522      0.076007      0.302848
# min      -60.000000      0.000000      0.000000      0.000000
# 25%      -10.375000      0.000000      0.035200      0.001400
# 50%       -7.200000      1.000000      0.048200      0.039900
# 75%       -5.089000      1.000000      0.083500      0.340000
# max        3.642000      1.000000      0.954000      0.996000
#
#        instrumentalness      liveness       valence         tempo  \
# count      50683.000000  50683.000000  50683.000000  50683.000000
# mean           0.225283      0.215425      0.433134    123.507682
# std            0.337049      0.184697      0.258779     29.621125
# min            0.000000      0.000000      0.000000      0.000000
# 25%            0.000018      0.098400      0.214000    100.683000
# 50%            0.005630      0.138000      0.405000    121.989000
# 75%            0.441000      0.289000      0.634000    141.639000
# max            0.999000      0.999000      0.993000    238.895000
#
#        time_signature
# count    50683.000000
# mean         3.898151
# std          0.419670
# min          0.000000
# 25%          4.000000
# 50%          4.000000
# 75%          4.000000
# max          5.000000

# %%
tags_distribution = df['tags'].str.split(',').explode().str.strip().value_counts()
print("\nTags Distribution:")
print(tags_distribution.head())
# Out:
# Tags Distribution:
# tags
# rock           10684
# indie           7287
# electronic      6594
# alternative     6274
# pop             4651
# Name: count, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 8))
sns.violinplot(x='genre', y='duration_ms', data=df, palette='Set2')
plt.title('Duration Distribution Across Genres')
plt.xlabel('Genre')
plt.ylabel('Duration (ms)')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Concatenate all tags into a single string
all_tags = ' '.join(df['tags'].dropna())

# Generate the word cloud
wordcloud = WordCloud(width=700, height=350, background_color='white', random_state=42).generate(all_tags)

# Display the generated word cloud using matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud for Tags')
plt.show()
# Out:
# Requirement already satisfied: wordcloud in c:\users\ken\anaconda3\lib\site-packages (1.9.3)
# Requirement already satisfied: matplotlib in c:\users\ken\anaconda3\lib\site-packages (from wordcloud) (3.7.1)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\ken\anaconda3\lib\site-packages (from wordcloud) (1.26.2)
# Requirement already satisfied: pillow in c:\users\ken\anaconda3\lib\site-packages (from wordcloud) (8.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ken\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\ken\anaconda3\lib\site-packages (from matplotlib->wordcloud) (5.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\ken\anaconda3\lib\site-packages (from matplotlib->wordcloud) (23.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ken\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\ken\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ken\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ken\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ken\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\ken\anaconda3\lib\site-packages (from importlib-resources>=3.2.0->matplotlib->wordcloud) (3.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\ken\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# WARNING: Ignoring invalid distribution -illow (c:\users\ken\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\ken\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\ken\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\ken\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\ken\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\ken\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\ken\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\ken\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\ken\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\ken\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\ken\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\ken\anaconda3\lib\site-packages)
# Requirement already satisfied: matplotlib in c:\users\ken\anaconda3\lib\site-packages (3.7.1)
# Requirement already satisfied: numpy in c:\users\ken\anaconda3\lib\site-packages (1.26.2)
# Requirement already satisfied: pillow in c:\users\ken\anaconda3\lib\site-packages (8.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ken\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ken\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in c:\users\ken\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ken\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ken\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ken\anaconda3\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\ken\anaconda3\lib\site-packages (from matplotlib) (5.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\ken\anaconda3\lib\site-packages (from matplotlib) (23.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\ken\anaconda3\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\ken\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[37], line 10
#       7 all_tags = ' '.join(df['tags'].dropna())
#       9 # Generate the word cloud
# ---> 10 wordcloud = WordCloud(width=700, height=350, background_color='white', random_state=42).generate(all_tags)
#      12 # Display the generated word cloud using matplotlib
#      13 plt.figure(figsize=(10, 5))
#
# File ~\anaconda3\lib\site-packages\wordcloud\wordcloud.py:642, in WordCloud.generate(self, text)
#     627 def generate(self, text):
#     628     """Generate wordcloud from text.
#     629
#     630     The input "text" is expected to be a natural text. If you pass a sorted
#    (...)
#     640     self
#     641     """
# --> 642     return self.generate_from_text(text)
#
# File ~\anaconda3\lib\site-packages\wordcloud\wordcloud.py:624, in WordCloud.generate_from_text(self, text)
#     607 """Generate wordcloud from text.
#     608
#     609 The input "text" is expected to be a natural text. If you pass a sorted
#    (...)
#     621 self
#     622 """
#     623 words = self.process_text(text)
# --> 624 self.generate_from_frequencies(words)
#     625 return self
#
# File ~\anaconda3\lib\site-packages\wordcloud\wordcloud.py:453, in WordCloud.generate_from_frequencies(self, frequencies, max_font_size)
#     451     font_size = self.height
#     452 else:
# --> 453     self.generate_from_frequencies(dict(frequencies[:2]),
#     454                                    max_font_size=self.height)
#     455     # find font sizes
#     456     sizes = [x[1] for x in self.layout_]
#
# File ~\anaconda3\lib\site-packages\wordcloud\wordcloud.py:511, in WordCloud.generate_from_frequencies(self, frequencies, max_font_size)
#     508 transposed_font = ImageFont.TransposedFont(
#     509     font, orientation=orientation)
#     510 # get size of resulting text
# --> 511 box_size = draw.textbbox((0, 0), word, font=transposed_font, anchor="lt")
#     512 # find possible places using integral image:
#     513 result = occupancy.sample_position(box_size[3] + self.margin,
#     514                                    box_size[2] + self.margin,
#     515                                    random_state)
#
# File ~\anaconda3\lib\site-packages\PIL\ImageDraw.py:657, in ImageDraw.textbbox(self, xy, text, font, anchor, spacing, align, direction, features, language, stroke_width, embedded_color)
#     655     font = self.getfont()
#     656 mode = "RGBA" if embedded_color else self.fontmode
# --> 657 bbox = font.getbbox(
#     658     text, mode, direction, features, language, stroke_width, anchor
#     659 )
#     660 return bbox[0] + xy[0], bbox[1] + xy[1], bbox[2] + xy[0], bbox[3] + xy[1]
#
# AttributeError: 'TransposedFont' object has no attribute 'getbbox'

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate the correlation matrix
correlation_matrix = df.corr()

# Create a heatmap using Seaborn
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Heatmap')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 5
#       2 import matplotlib.pyplot as plt
#       4 # Calculate the correlation matrix
# ----> 5 correlation_matrix = df.corr()
#       7 # Create a heatmap using Seaborn
#       8 plt.figure(figsize=(12, 10))
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:10704, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10702 cols = data.columns
#   10703 idx = cols.copy()
# > 10704 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10706 if method == "pearson":
#   10707     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:1889, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1887 if dtype is not None:
#    1888     dtype = np.dtype(dtype)
# -> 1889 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1890 if result.dtype is not dtype:
#    1891     result = np.array(result, dtype=dtype, copy=False)
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1656, in BlockManager.as_array(self, dtype, copy, na_value)
#    1654         arr.flags.writeable = False
#    1655 else:
# -> 1656     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1657     # The underlying data was copied within _interleave, so no need
#    1658     # to further copy if copy=True or setting na_value
#    1660 if na_value is lib.no_default:
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1715, in BlockManager._interleave(self, dtype, na_value)
#    1713     else:
#    1714         arr = blk.get_values(dtype)
# -> 1715     result[rl.indexer] = arr
#    1716     itemmask[rl.indexer] = 1
#    1718 if not itemmask.all():
#
# ValueError: could not convert string to float: 'TRIOREW128F424EAF0'

# %% [markdown]
# #### 1. Valence and Danceability (Correlation: 0.54):
# A positive correlation of 0.54 suggests a moderate positive linear relationship between valence and danceability.
# As valence increases, danceability tends to increase as well, and vice versa.
# #### 2. Loudness and Energy (Correlation: 0.78):
# A strong positive correlation of 0.78 indicates a robust positive linear relationship between loudness and energy.
# Higher loudness levels are associated with higher energy in the music.
# #### 3. Acousticness and Energy (Correlation: -0.73):
# A strong negative correlation of -0.73 implies a robust negative linear relationship between acousticness and energy.
# As the level of acousticness decreases (more electronic or non-acoustic), energy tends to increase.
# #### 4. Acousticness and Loudness (Correlation: -0.61):
# A strong negative correlation of -0.61 suggests a robust negative linear relationship between acousticness and loudness.
# Less acoustic (more electronic) tracks tend to have higher loudness levels, and vice versa.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'genre' is the column containing genre information in your DataFrame
plt.figure(figsize=(12, 6))
sns.countplot(x='genre', data=df, palette='viridis')
plt.title('Distribution of Music Genres')
plt.xlabel('Genre')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='year', data=df, palette='viridis')
plt.title('Distribution of Songs Over the Years')
plt.xlabel('Year')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x='year', y='danceability', data=df, ci=None)
plt.title('Danceability Over the Years')
plt.xlabel('Year')
plt.ylabel('Danceability')
plt.show()
# Out:
# C:\Users\Ken\AppData\Local\Temp\ipykernel_13196\2458810390.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x='year', y='danceability', data=df, ci=None)
# C:\Users\Ken\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Ken\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(12, 6))
sns.violinplot(x='genre', y='instrumentalness', data=df, palette='Set2')
plt.title('Instrumentalness Distribution Across Genres')
plt.xlabel('Genre')
plt.ylabel('Instrumentalness')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='key', data=df, palette='viridis')
plt.title('Distribution of Musical Keys')
plt.xlabel('Key')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='time_signature', data=df, palette='viridis')
plt.title('Distribution of Time Signatures')
plt.xlabel('Time Signature')
plt.ylabel('Count')
plt.show()

# %%
sns.pairplot(df[['danceability', 'energy', 'loudness', 'valence']])
plt.suptitle('Pairwise Relationships between Audio Features', y=1.02)
plt.show()
# Out:
# C:\Users\Ken\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Ken\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Ken\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Ken\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='genre', y='duration_ms', data=df, palette='viridis')
plt.title('Duration Distribution Across Genres')
plt.xlabel('Genre')
plt.ylabel('Duration (ms)')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['duration_ms'], bins=30, kde=True, color='skyblue')
plt.title('Distribution of Song Durations')
plt.xlabel('Duration (ms)')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\Ken\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import plotly.express as px

# Create a Dash web application
app = dash.Dash(__name__)

# Define the layout of the dashboard
app.layout = html.Div([
    html.H1("Music Analysis Dashboard"),
    
    # Dropdown for selecting features
    html.Label("Select Feature:"),
    dcc.Dropdown(
        id='feature-dropdown',
        options=[
            {'label': 'year', 'value': 'year'},
            {'label': 'Danceability', 'value': 'danceability'},
            {'label': 'Energy', 'value': 'energy'},
            {'label': 'Valence', 'value': 'valence'},
            {'label': 'duration_ms', 'value': 'duration_ms'},
            {'label': 'key', 'value': 'key'},
            {'label': 'loudness', 'value': 'loudness'},
            {'label': 'speechiness', 'value': 'speechiness'},
            {'label': 'acousticness', 'value': 'acousticness'},
            {'label': 'instrumentalness', 'value': 'instrumentalness'},
            {'label': 'liveness', 'value': 'liveness'},
            {'label': 'valence', 'value': 'valence'},
            {'label': 'tempo', 'value': 'tempo'},
            {'label': 'time_signature', 'value': 'time_signature'},
            # Add more features as needed
        ],
        value='danceability'  # Default feature
    ),
    
    # Graph to display feature distribution
    dcc.Graph(id='feature-distribution'),

    # Add more components as needed
])

# Define callback to update graph based on feature selection
@app.callback(
    Output('feature-distribution', 'figure'),
    [Input('feature-dropdown', 'value')]
)
def update_graph(selected_feature):
    # Create a distribution plot based on the selected feature
    fig = px.histogram(df, x=selected_feature, title=f'Distribution of {selected_feature.capitalize()}')
    return fig

# Run the application
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
# C:\Users\Ken\AppData\Local\Temp\ipykernel_13196\2721233488.py:2: UserWarning:
# The dash_core_components package is deprecated. Please replace
# `import dash_core_components as dcc` with `from dash import dcc`
#   import dash_core_components as dcc
# C:\Users\Ken\AppData\Local\Temp\ipykernel_13196\2721233488.py:3: UserWarning:
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`
#   import dash_html_components as html
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### Now lets use the user data to create additional features

# %%
df1.head()
# Out:
#              track_id                                   user_id  playcount
# 0  TRIRLYL128F42539D1  b80344d063b5ccb3212f76538f3d9e43d87dca9e          1
# 1  TRFUPBA128F934F7E1  b80344d063b5ccb3212f76538f3d9e43d87dca9e          1
# 2  TRLQPQJ128F42AA94F  b80344d063b5ccb3212f76538f3d9e43d87dca9e          1
# 3  TRTUCUY128F92E1D24  b80344d063b5ccb3212f76538f3d9e43d87dca9e          1
# 4  TRHDDQG12903CB53EE  b80344d063b5ccb3212f76538f3d9e43d87dca9e          1

# %%
df1.tail()
# Out:
#                    track_id                                   user_id  \
# 9711296  TRBKFKL128E078ED76  b7815dbb206eb2831ce0fe040d0aa537e2e800f7
# 9711297  TRYFXPG128E078ECBD  b7815dbb206eb2831ce0fe040d0aa537e2e800f7
# 9711298  TROBUUZ128F4263002  b7815dbb206eb2831ce0fe040d0aa537e2e800f7
# 9711299  TROEWXC128F148C83E  b7815dbb206eb2831ce0fe040d0aa537e2e800f7
# 9711300  TROHQNO128F146ECCB  b7815dbb206eb2831ce0fe040d0aa537e2e800f7
#
#          playcount
# 9711296          1
# 9711297          1
# 9711298          1
# 9711299          1
# 9711300          1

# %%
import pandas as pd

# Assuming df1 is the subset dataset and df is the other dataset
# with columns track_id, name, artist, and other features

# Generate track-level features
track_playcount = df1.groupby('track_id')['playcount'].agg(['sum', 'mean', 'max', 'min']).reset_index()
track_playcount.columns = ['track_id', 'total_playcount_track', 'average_playcount_track', 'max_playcount_track', 'min_playcount_track']

# Merge track-level features with the other dataset based on track_id
df_merged = pd.merge(df, track_playcount, on='track_id', how='left')

# Now df_merged contains the original dataset with additional playcount features

# %%
df_merged.head()
# Out:
#              track_id             name           artist  \
# 0  TRIOREW128F424EAF0   Mr. Brightside      The Killers
# 1  TRRIVDJ128F429B0E8       Wonderwall            Oasis
# 2  TROUVHL128F426C441  Come as You Are          Nirvana
# 3  TRUEIND128F93038C4      Take Me Out  Franz Ferdinand
# 4  TRLNZBD128F935E4D8            Creep        Radiohead
#
#                                  spotify_preview_url              spotify_id  \
# 0  https://p.scdn.co/mp3-preview/4d26180e6961fd46...  09ZQ5TmUG8TSL56n0knqrj
# 1  https://p.scdn.co/mp3-preview/d012e536916c927b...  06UfBBDISthj1ZJAtX4xjj
# 2  https://p.scdn.co/mp3-preview/a1c11bb1cb231031...  0keNu0t0tqsWtExGM3nT1D
# 3  https://p.scdn.co/mp3-preview/399c401370438be4...  0ancVQ9wEcHVd0RrGICTE4
# 4  https://p.scdn.co/mp3-preview/e7eb60e9466bc3a2...  01QoK9DA7VTeTSE3MNzp4I
#
#                                                 tags genre  year  duration_ms  \
# 0  rock, alternative, indie, alternative_rock, in...   NaN  2004       222200
# 1  rock, alternative, indie, pop, alternative_roc...   NaN  2006       258613
# 2   rock, alternative, alternative_rock, 90s, grunge   RnB  1991       218920
# 3  rock, alternative, indie, alternative_rock, in...   NaN  2004       237026
# 4  rock, alternative, indie, alternative_rock, in...   RnB  2008       238640
#
#    danceability  ...  acousticness  instrumentalness  liveness  valence  \
# 0         0.355  ...      0.001190          0.000000    0.0971    0.240
# 1         0.409  ...      0.000807          0.000000    0.2070    0.651
# 2         0.508  ...      0.000175          0.000459    0.0878    0.543
# 3         0.279  ...      0.000389          0.000655    0.1330    0.490
# 4         0.515  ...      0.010200          0.000141    0.1290    0.104
#
#      tempo  time_signature  total_playcount_track  average_playcount_track  \
# 0  148.114               4                  162.0                 3.951220
# 1  174.426               4                  995.0                 2.632275
# 2  120.012               4                    NaN                      NaN
# 3  104.560               4                   21.0                 1.050000
# 4   91.841               4                    NaN                      NaN
#
#    max_playcount_track  min_playcount_track
# 0                 52.0                  1.0
# 1                 27.0                  1.0
# 2                  NaN                  NaN
# 3                  2.0                  1.0
# 4                  NaN                  NaN
#
# [5 rows x 25 columns]

# %%
print("\nMissing Values:")
print(df_merged.isnull().sum())
# Out:
# Missing Values:
# track_id                       0
# name                           0
# artist                         0
# spotify_preview_url            0
# spotify_id                     0
# tags                        1127
# genre                      28335
# year                           0
# duration_ms                    0
# danceability                   0
# energy                         0
# key                            0
# loudness                       0
# mode                           0
# speechiness                    0
# acousticness                   0
# instrumentalness               0
# liveness                       0
# valence                        0
# tempo                          0
# time_signature                 0
# total_playcount_track      20224
# average_playcount_track    20224
# max_playcount_track        20224
# min_playcount_track        20224
# dtype: int64

# %%
df_merged1 = df_merged.dropna().reset_index(drop=True)

# %%
print("\nMissing Values:")
print(df_merged1.isnull().sum())
# Out:
# Missing Values:
# track_id                   0
# name                       0
# artist                     0
# spotify_preview_url        0
# spotify_id                 0
# tags                       0
# genre                      0
# year                       0
# duration_ms                0
# danceability               0
# energy                     0
# key                        0
# loudness                   0
# mode                       0
# speechiness                0
# acousticness               0
# instrumentalness           0
# liveness                   0
# valence                    0
# tempo                      0
# time_signature             0
# total_playcount_track      0
# average_playcount_track    0
# max_playcount_track        0
# min_playcount_track        0
# dtype: int64

# %%
print("\nUnique Values:")
print(df_merged1.nunique())
# Out:
# Unique Values:
# track_id                   16119
# name                       16119
# artist                      4144
# spotify_preview_url        16116
# spotify_id                 16119
# tags                        8351
# genre                         15
# year                          64
# duration_ms                11632
# danceability                 925
# energy                      1136
# key                           12
# loudness                    9286
# mode                           2
# speechiness                 1176
# acousticness                4340
# instrumentalness            4174
# liveness                    1530
# valence                     1498
# tempo                      14070
# time_signature                 5
# total_playcount_track       3294
# average_playcount_track     9720
# max_playcount_track          352
# min_playcount_track           16
# dtype: int64

# %%
# Assuming df is your original DataFrame with features and df_merged contains the standardized and scaled playcount features

# Merge the standardized and scaled playcount features with the original DataFrame based on a common column (e.g., 'track_id' or 'user_id')
df_final = pd.merge(df, df_merged[['track_id', 'total_playcount_track', 'average_playcount_track', 'max_playcount_track', 'min_playcount_track']], on='track_id', how='left')

# Now df_final contains the original features along with the standardized and scaled playcount features

# %%
# Assuming df is your original DataFrame with features and df_merged contains the standardized and scaled playcount features

# Merge the standardized and scaled playcount features with the original DataFrame based on a common column (e.g., 'track_id' or 'user_id')
df_final = pd.merge(df, df_merged[['track_id', 'total_playcount_track', 'average_playcount_track', 'max_playcount_track', 'min_playcount_track']], on='track_id', how='left')

# Now df_final contains the original features along with the standardized and scaled playcount features

# %%
df_final.head()
# Out:
#              track_id             name           artist  \
# 0  TRIOREW128F424EAF0   Mr. Brightside      The Killers
# 1  TRRIVDJ128F429B0E8       Wonderwall            Oasis
# 2  TROUVHL128F426C441  Come as You Are          Nirvana
# 3  TRUEIND128F93038C4      Take Me Out  Franz Ferdinand
# 4  TRLNZBD128F935E4D8            Creep        Radiohead
#
#                                  spotify_preview_url              spotify_id  \
# 0  https://p.scdn.co/mp3-preview/4d26180e6961fd46...  09ZQ5TmUG8TSL56n0knqrj
# 1  https://p.scdn.co/mp3-preview/d012e536916c927b...  06UfBBDISthj1ZJAtX4xjj
# 2  https://p.scdn.co/mp3-preview/a1c11bb1cb231031...  0keNu0t0tqsWtExGM3nT1D
# 3  https://p.scdn.co/mp3-preview/399c401370438be4...  0ancVQ9wEcHVd0RrGICTE4
# 4  https://p.scdn.co/mp3-preview/e7eb60e9466bc3a2...  01QoK9DA7VTeTSE3MNzp4I
#
#                                                 tags genre  year  duration_ms  \
# 0  rock, alternative, indie, alternative_rock, in...   NaN  2004       222200
# 1  rock, alternative, indie, pop, alternative_roc...   NaN  2006       258613
# 2   rock, alternative, alternative_rock, 90s, grunge   RnB  1991       218920
# 3  rock, alternative, indie, alternative_rock, in...   NaN  2004       237026
# 4  rock, alternative, indie, alternative_rock, in...   RnB  2008       238640
#
#    danceability  ...  acousticness  instrumentalness  liveness  valence  \
# 0         0.355  ...      0.001190          0.000000    0.0971    0.240
# 1         0.409  ...      0.000807          0.000000    0.2070    0.651
# 2         0.508  ...      0.000175          0.000459    0.0878    0.543
# 3         0.279  ...      0.000389          0.000655    0.1330    0.490
# 4         0.515  ...      0.010200          0.000141    0.1290    0.104
#
#      tempo  time_signature  total_playcount_track  average_playcount_track  \
# 0  148.114               4                  162.0                 3.951220
# 1  174.426               4                  995.0                 2.632275
# 2  120.012               4                    NaN                      NaN
# 3  104.560               4                   21.0                 1.050000
# 4   91.841               4                    NaN                      NaN
#
#    max_playcount_track  min_playcount_track
# 0                 52.0                  1.0
# 1                 27.0                  1.0
# 2                  NaN                  NaN
# 3                  2.0                  1.0
# 4                  NaN                  NaN
#
# [5 rows x 25 columns]

# %%
print("\nMissing Values:")
print(df_final.isnull().sum())
# Out:
# Missing Values:
# track_id                       0
# name                           0
# artist                         0
# spotify_preview_url            0
# spotify_id                     0
# tags                        1127
# genre                      28335
# year                           0
# duration_ms                    0
# danceability                   0
# energy                         0
# key                            0
# loudness                       0
# mode                           0
# speechiness                    0
# acousticness                   0
# instrumentalness               0
# liveness                       0
# valence                        0
# tempo                          0
# time_signature                 0
# total_playcount_track      20224
# average_playcount_track    20224
# max_playcount_track        20224
# min_playcount_track        20224
# dtype: int64

# %%
df_final=df_final.dropna().reset_index(drop=True)

# %%
df_final
# Out:
#                  track_id                  name                 artist  \
# 0      TRIODZU128E078F3E2      Under the Bridge  Red Hot Chili Peppers
# 1      TRYEZGE128F92D04C8        Feel Good Inc.               Gorillaz
# 2      TRIQWYH128F1486062      Paranoid Android              Radiohead
# 3      TRUOEWJ128F9345A85    Stairway to Heaven           Led Zeppelin
# 4      TRNNGMK128F423F034     Where Is My Mind?                 Pixies
# ...                   ...                   ...                    ...
# 16114  TRIMGHU128F93443E8          My Sweet Dog            Hi-Standard
# 16115  TRPJBMG128F92D164E       Stretch My Arms                   Fact
# 16116  TRTBIEH128F427C13C  Let It All Come Down   Boom Boom Satellites
# 16117  TRNIBCG128F92E4555               Keyword  9mm Parabellum Bullet
# 16118  TRPIGDW12903CDEB2D       Slip of the Lip                   Fact
#
#                                      spotify_preview_url  \
# 0      https://p.scdn.co/mp3-preview/90e41778392f27b6...
# 1      https://p.scdn.co/mp3-preview/7388c425022ced92...
# 2      https://p.scdn.co/mp3-preview/d68bd7fa4f0bd86e...
# 3      https://p.scdn.co/mp3-preview/6879ce58805099f6...
# 4      https://p.scdn.co/mp3-preview/d4a375a9c19d4ea8...
# ...                                                  ...
# 16114  https://p.scdn.co/mp3-preview/4e6746eb6cfb8e16...
# 16115  https://p.scdn.co/mp3-preview/d4f92d8d34185280...
# 16116  https://p.scdn.co/mp3-preview/5d8e0600d03bf0e4...
# 16117  https://p.scdn.co/mp3-preview/1cb3b1abdab3baf6...
# 16118  https://p.scdn.co/mp3-preview/cf64490291f9a600...
#
#                    spotify_id  \
# 0      06zh28PcYIFvNOAz5Wq2Xb
# 1      09xrHi86kLkEIzDLZiHNnv
# 2      0bomiLGPTUNyk3mV19pbwN
# 3      03hLW9osM6UuNqlpwL8XPo
# 4      0DJU6KGwdkxEPCy3BZ3UZY
# ...                       ...
# 16114  1QI6h4zJmmEk3Dl0nM31q7
# 16115  1QsJi0afbAvbnZHO8AtOLD
# 16116  47tFsBHLZ1ETuunLZKtgAN
# 16117  5lQatPubYHgBIK22beDTi4
# 16118  0PG7cpyNzRehf1YNIbAsol
#
#                                                     tags  genre  year  \
# 0         rock, alternative, alternative_rock, 90s, funk    Pop  2003
# 1      rock, electronic, alternative, indie, pop, alt...    RnB  2010
# 2      rock, electronic, alternative, indie, alternat...   Jazz  2012
# 3      rock, classic_rock, hard_rock, progressive_roc...   Punk  2013
# 4      rock, alternative, indie, alternative_rock, in...   Rock  2005
# ...                                                  ...    ...   ...
# 16114                                    punk, punk_rock   Punk  1997
# 16115                         metal, metalcore, japanese  Metal  2009
# 16116                               electronic, japanese   Rock  1998
# 16117                                     rock, japanese   Rock  2008
# 16118                        alternative_rock, punk_rock   Rock  2010
#
#        duration_ms  danceability  ...  acousticness  instrumentalness  \
# 0           265506         0.554  ...      0.016800          0.000534
# 1           223106         0.809  ...      0.033700          0.001410
# 2           384933         0.232  ...      0.052300          0.006060
# 3           488019         0.354  ...      0.625000          0.011200
# 4           230093         0.514  ...      0.007800          0.000859
# ...            ...           ...  ...           ...               ...
# 16114        95293         0.640  ...      0.003550          0.153000
# 16115       241933         0.362  ...      0.002130          0.005370
# 16116       282093         0.570  ...      0.028600          0.000708
# 16117       203226         0.279  ...      0.000811          0.000041
# 16118       183640         0.423  ...      0.000986          0.000002
#
#        liveness  valence    tempo  time_signature  total_playcount_track  \
# 0        0.1360    0.513   84.275               4                  990.0
# 1        0.8260    0.832  138.556               4                   98.0
# 2        0.1180    0.299   81.849               4                 1075.0
# 3        0.3500    0.212   80.360               4                  566.0
# 4        0.0802    0.212   82.104               4                32185.0
# ...         ...      ...      ...             ...                    ...
# 16114    0.0676    0.768  119.388               4                   58.0
# 16115    0.1830    0.442  172.951               4                   83.0
# 16116    0.1640    0.118  103.008               4                   56.0
# 16117    0.0477    0.256  192.071               4                   12.0
# 16118    0.3790    0.224  100.080               4                   93.0
#
#        average_playcount_track  max_playcount_track  min_playcount_track
# 0                     2.519084                 41.0                  1.0
# 1                     2.333333                  8.0                  1.0
# 2                     2.239583                 22.0                  1.0
# 3                     1.938356                 38.0                  1.0
# 4                     3.257261                236.0                  1.0
# ...                        ...                  ...                  ...
# 16114                 2.230769                 10.0                  1.0
# 16115                 3.074074                 24.0                  1.0
# 16116                 3.294118                 12.0                  1.0
# 16117                 2.000000                  5.0                  1.0
# 16118                 4.043478                 35.0                  1.0
#
# [16119 rows x 25 columns]

# %%
print("\nMissing Values:")
print(df_final.isnull().sum())
# Out:
# Missing Values:
# track_id                   0
# name                       0
# artist                     0
# spotify_preview_url        0
# spotify_id                 0
# tags                       0
# genre                      0
# year                       0
# duration_ms                0
# danceability               0
# energy                     0
# key                        0
# loudness                   0
# mode                       0
# speechiness                0
# acousticness               0
# instrumentalness           0
# liveness                   0
# valence                    0
# tempo                      0
# time_signature             0
# total_playcount_track      0
# average_playcount_track    0
# max_playcount_track        0
# min_playcount_track        0
# dtype: int64

# %%
df_final.shape
# Out:
# (16119, 25)

# %%
df_final.head()
# Out:
#              track_id                name                 artist  \
# 0  TRIODZU128E078F3E2    Under the Bridge  Red Hot Chili Peppers
# 1  TRYEZGE128F92D04C8      Feel Good Inc.               Gorillaz
# 2  TRIQWYH128F1486062    Paranoid Android              Radiohead
# 3  TRUOEWJ128F9345A85  Stairway to Heaven           Led Zeppelin
# 4  TRNNGMK128F423F034   Where Is My Mind?                 Pixies
#
#                                  spotify_preview_url              spotify_id  \
# 0  https://p.scdn.co/mp3-preview/90e41778392f27b6...  06zh28PcYIFvNOAz5Wq2Xb
# 1  https://p.scdn.co/mp3-preview/7388c425022ced92...  09xrHi86kLkEIzDLZiHNnv
# 2  https://p.scdn.co/mp3-preview/d68bd7fa4f0bd86e...  0bomiLGPTUNyk3mV19pbwN
# 3  https://p.scdn.co/mp3-preview/6879ce58805099f6...  03hLW9osM6UuNqlpwL8XPo
# 4  https://p.scdn.co/mp3-preview/d4a375a9c19d4ea8...  0DJU6KGwdkxEPCy3BZ3UZY
#
#                                                 tags genre  year  duration_ms  \
# 0     rock, alternative, alternative_rock, 90s, funk   Pop  2003       265506
# 1  rock, electronic, alternative, indie, pop, alt...   RnB  2010       223106
# 2  rock, electronic, alternative, indie, alternat...  Jazz  2012       384933
# 3  rock, classic_rock, hard_rock, progressive_roc...  Punk  2013       488019
# 4  rock, alternative, indie, alternative_rock, in...  Rock  2005       230093
#
#    danceability  ...  acousticness  instrumentalness  liveness  valence  \
# 0         0.554  ...        0.0168          0.000534    0.1360    0.513
# 1         0.809  ...        0.0337          0.001410    0.8260    0.832
# 2         0.232  ...        0.0523          0.006060    0.1180    0.299
# 3         0.354  ...        0.6250          0.011200    0.3500    0.212
# 4         0.514  ...        0.0078          0.000859    0.0802    0.212
#
#      tempo  time_signature  total_playcount_track  average_playcount_track  \
# 0   84.275               4                  990.0                 2.519084
# 1  138.556               4                   98.0                 2.333333
# 2   81.849               4                 1075.0                 2.239583
# 3   80.360               4                  566.0                 1.938356
# 4   82.104               4                32185.0                 3.257261
#
#    max_playcount_track  min_playcount_track
# 0                 41.0                  1.0
# 1                  8.0                  1.0
# 2                 22.0                  1.0
# 3                 38.0                  1.0
# 4                236.0                  1.0
#
# [5 rows x 25 columns]

# %%
df_final['text_features'] = df_final['name'] + ' ' + df_final['artist'] + ' ' + df_final['tags'] + ' ' + df_final['genre']

# %%
df_final['text_features'].head()
# Out:
# 0    Under the Bridge Red Hot Chili Peppers rock, a...
# 1    Feel Good Inc. Gorillaz rock, electronic, alte...
# 2    Paranoid Android Radiohead rock, electronic, a...
# 3    Stairway to Heaven Led Zeppelin rock, classic_...
# 4    Where Is My Mind? Pixies rock, alternative, in...
# Name: text_features, dtype: object

# %%
df_final['text_features']=df_final['text_features'].str.lower().replace(r'^\w\s','').replace(r'\n','', regex=True)
audio_features = df_final[['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
                     'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature']]

# %%
df_final['text_features']
# Out:
# 0        under the bridge red hot chili peppers rock, a...
# 1        feel good inc. gorillaz rock, electronic, alte...
# 2        paranoid android radiohead rock, electronic, a...
# 3        stairway to heaven led zeppelin rock, classic_...
# 4        where is my mind? pixies rock, alternative, in...
#                                ...
# 16114        my sweet dog hi-standard punk, punk_rock punk
# 16115    stretch my arms fact metal, metalcore, japanes...
# 16116    let it all come down boom boom satellites elec...
# 16117    keyword 9mm parabellum bullet rock, japanese rock
# 16118    slip of the lip fact alternative_rock, punk_ro...
# Name: text_features, Length: 16119, dtype: object

# %%
df_final['text_features'].shape
# Out:
# (16119,)

# %%
audio_features
# Out:
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0             0.554   0.490    4    -8.046     1       0.0457      0.016800
# 1             0.809   0.720    6    -7.776     1       0.1360      0.033700
# 2             0.232   0.800    5    -6.863     1       0.0573      0.052300
# 3             0.354   0.361    9   -12.722     0       0.0509      0.625000
# 4             0.514   0.435    4   -13.517     1       0.0353      0.007800
# ...             ...     ...  ...       ...   ...          ...           ...
# 16114         0.640   0.819    7    -7.160     1       0.0548      0.003550
# 16115         0.362   0.951   10    -4.621     1       0.1170      0.002130
# 16116         0.570   0.926    1    -5.766     0       0.0672      0.028600
# 16117         0.279   0.974    8    -3.481     1       0.1260      0.000811
# 16118         0.423   0.980    2    -4.068     1       0.1840      0.000986
#
#        instrumentalness  liveness  valence    tempo  time_signature
# 0              0.000534    0.1360    0.513   84.275               4
# 1              0.001410    0.8260    0.832  138.556               4
# 2              0.006060    0.1180    0.299   81.849               4
# 3              0.011200    0.3500    0.212   80.360               4
# 4              0.000859    0.0802    0.212   82.104               4
# ...                 ...       ...      ...      ...             ...
# 16114          0.153000    0.0676    0.768  119.388               4
# 16115          0.005370    0.1830    0.442  172.951               4
# 16116          0.000708    0.1640    0.118  103.008               4
# 16117          0.000041    0.0477    0.256  192.071               4
# 16118          0.000002    0.3790    0.224  100.080               4
#
# [16119 rows x 12 columns]

# %%
df_final["text_features"].head(20)
# Out:
# 0     under the bridge red hot chili peppers rock, a...
# 1     feel good inc. gorillaz rock, electronic, alte...
# 2     paranoid android radiohead rock, electronic, a...
# 3     stairway to heaven led zeppelin rock, classic_...
# 4     where is my mind? pixies rock, alternative, in...
# 5     heart-shaped box nirvana rock, alternative, al...
# 6     in bloom nirvana rock, alternative, alternativ...
# 7     float on modest mouse rock, alternative, indie...
# 8     can't stop red hot chili peppers rock, alterna...
# 9     naïve the kooks rock, alternative, indie, indi...
# 10    in my place coldplay rock, alternative, indie,...
# 11    mardy bum arctic monkeys rock, alternative, in...
# 12    sweet home alabama lynyrd skynyrd rock, classi...
# 13    speed of sound coldplay rock, alternative, ind...
# 14    sultans of swing dire straits rock, classic_ro...
# 15    last nite the strokes rock, alternative, indie...
# 16    don't stop me now queen rock, classic_rock, 80...
# 17    fluorescent adolescent arctic monkeys rock, al...
# 18    buddy holly weezer rock, alternative, indie, a...
# 19    fortunate son creedence clearwater revival roc...
# Name: text_features, dtype: object

# %%
df_sample=df_final.sample(1800).reset_index(drop=True)

# %%
df_sample.shape
# Out:
# (1800, 26)

# %%
df_sample
# Out:
#                 track_id                           name              artist  \
# 0     TRYLITA128F429BC02             40 Years Back Come            Röyksopp
# 1     TRSOCHC128F92D5152                   Omen Reprise         The Prodigy
# 2     TRATGZC12903CF4223                     Black Trip              Samael
# 3     TRLVILD128F933BC9A           Hush Hush; Hush Hush  The Pussycat Dolls
# 4     TRUOVRF128E07822E6                           Lull         Andrew Bird
# ...                  ...                            ...                 ...
# 1795  TRBLDQQ128F92E58B4                       Tuolumne        Eddie Vedder
# 1796  TRCCOHD128F148C233   Popular Mechanics for Lovers              Beulah
# 1797  TRUPZCY128F4270FCC  I Wanted You To Feel The Same     The Radio Dept.
# 1798  TRMKYZN128F93421D3                   Action Woman          The Litter
# 1799  TRWPDSU128F4230A62                     The Sinner    Memphis May Fire
#
#                                     spotify_preview_url  \
# 0     https://p.scdn.co/mp3-preview/2bf2dd711325634e...
# 1     https://p.scdn.co/mp3-preview/8b9484a40e22d731...
# 2     https://p.scdn.co/mp3-preview/83d4ed0adba86c98...
# 3     https://p.scdn.co/mp3-preview/629fb6dfdccd89c9...
# 4     https://p.scdn.co/mp3-preview/f47c89a819282b01...
# ...                                                 ...
# 1795  https://p.scdn.co/mp3-preview/4a4cf870f4815266...
# 1796  https://p.scdn.co/mp3-preview/496d0c1e49163e55...
# 1797  https://p.scdn.co/mp3-preview/31c9e409c5006698...
# 1798  https://p.scdn.co/mp3-preview/3cbeb84d445f13f6...
# 1799  https://p.scdn.co/mp3-preview/61c72645899a3d66...
#
#                   spotify_id  \
# 0     40GkVUz0J8aAdmTb2eeKxF
# 1     04NzY6lfr99gmtF9hGA5yv
# 2     3PxrnoaU1tWbADwqmi28Zr
# 3     00fZi3zmINnLLCSiXMvImX
# 4     0f33Lrvmcxnnz433m0WvKO
# ...                      ...
# 1795  2X7geNPv8okwUwmNhADJqd
# 1796  2Cla3UoHpM6u92PeGzBytm
# 1797  0HIBfeCis0OvV5orUMgSN5
# 1798  0LgUtUlpqn4GJ1SEo8mIvY
# 1799  0VVrKklHWHn8ogjNBXyEiK
#
#                                                    tags       genre  year  \
# 0     electronic, ambient, chillout, downtempo, loun...  Electronic  2001
# 1                        electronic, industrial, techno  Electronic  2009
# 2                                           black_metal       Metal  2007
# 3                                     pop, dance, cover         Pop  2009
# 4     indie, folk, singer_songwriter, acoustic, amer...        Rock  2003
# ...                                                 ...         ...   ...
# 1795  rock, alternative, folk, instrumental, singer_...        Rock  2007
# 1796                 indie, soundtrack, indie_pop, love        Rock  2001
# 1797                                     indie, swedish        Rock  1900
# 1798                              60s, psychedelic_rock        Rock  2009
# 1799                           metalcore, post_hardcore  Electronic  2011
#
#       duration_ms  danceability  ...  instrumentalness  liveness  valence  \
# 0          285560         0.360  ...          0.918000    0.1530    0.101
# 1          134160         0.362  ...          0.123000    0.0724    0.153
# 2          197973         0.359  ...          0.898000    0.3540    0.279
# 3          252066         0.644  ...          0.000000    0.3190    0.536
# 4          309560         0.438  ...          0.003650    0.1100    0.304
# ...           ...           ...  ...               ...       ...      ...
# 1795        60306         0.352  ...          0.977000    0.1190    0.329
# 1796       184106         0.565  ...          0.001450    0.1980    0.767
# 1797       151040         0.627  ...          0.092300    0.2980    0.273
# 1798       153226         0.326  ...          0.000059    0.1700    0.495
# 1799       242066         0.206  ...          0.000000    0.3130    0.410
#
#         tempo  time_signature  total_playcount_track  average_playcount_track  \
# 0     115.974               4                 1120.0                 1.769352
# 1      89.381               5                 2148.0                 3.304615
# 2      90.816               4                    8.0                 2.666667
# 3     129.508               4                 1001.0                 2.909884
# 4     117.680               4                 1893.0                 2.375157
# ...       ...             ...                    ...                      ...
# 1795  107.674               4                 2628.0                 2.082409
# 1796  137.792               4                  776.0                 2.155556
# 1797  114.984               4                  737.0                 1.949735
# 1798  133.961               4                  128.0                 2.461538
# 1799  128.468               4                  646.0                 4.581560
#
#       max_playcount_track  min_playcount_track  \
# 0                    39.0                  1.0
# 1                   135.0                  1.0
# 2                     3.0                  2.0
# 3                    34.0                  1.0
# 4                    92.0                  1.0
# ...                   ...                  ...
# 1795                 40.0                  1.0
# 1796                 34.0                  1.0
# 1797                 11.0                  1.0
# 1798                 15.0                  1.0
# 1799                 39.0                  1.0
#
#                                           text_features
# 0     40 years back come röyksopp electronic, ambien...
# 1     omen reprise the prodigy electronic, industria...
# 2                   black trip samael black_metal metal
# 3     hush hush; hush hush the pussycat dolls pop, d...
# 4     lull andrew bird indie, folk, singer_songwrite...
# ...                                                 ...
# 1795  tuolumne eddie vedder rock, alternative, folk,...
# 1796  popular mechanics for lovers beulah indie, sou...
# 1797  i wanted you to feel the same the radio dept. ...
# 1798  action woman the litter 60s, psychedelic_rock ...
# 1799  the sinner memphis may fire metalcore, post_ha...
#
# [1800 rows x 26 columns]

# %%
import nltk
from nltk.stem.porter import PorterStemmer

# %%
stemmer=PorterStemmer()

# %%
def token(txt):
    token=nltk.word_tokenize(txt)
    a=[stemmer.stem(w) for w in token]
    return " ".join(a)

# %%
token(" under the bridge red hot chili peppers rock,")
# Out:
# 'under the bridg red hot chili pepper rock ,'

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel, cosine_similarity

# %%
df_sample['text_features'].apply(lambda x:token(x))
# Out:
# 0       40 year back come röyksopp electron , ambient ...
# 1       omen repris the prodigi electron , industri , ...
# 2                       black trip samael black_met metal
# 3       hush hush ; hush hush the pussycat doll pop , ...
# 4       lull andrew bird indi , folk , singer_songwrit...
#                               ...
# 1795    tuolumn eddi vedder rock , altern , folk , ins...
# 1796    popular mechan for lover beulah indi , soundtr...
# 1797    i want you to feel the same the radio dept . i...
# 1798    action woman the litter 60 , psychedelic_rock ...
# 1799    the sinner memphi may fire metalcor , post_har...
# Name: text_features, Length: 1800, dtype: object

# %%
tfid = TfidfVectorizer(analyzer="word",stop_words="english")

# %%
matrix=tfid.fit_transform(df_sample['text_features'])

# %%
matrix.shape
# Out:
# (1800, 3647)

# %%
similar=cosine_similarity(matrix)

# %%
similar[0]
# Out:
# array([1.        , 0.09745116, 0.        , ..., 0.        , 0.        ,
#        0.05833903])

# %%
df_sample.tail(20)
# Out:
#                 track_id                                  name  \
# 1780  TRXRWIT128F92E7346                            All Aboard
# 1781  TRAZLOG12903CF1086                               Trooper
# 1782  TRIXYQV12903CF5AF5                 Inside the Torn Apart
# 1783  TRKHUJI128F146CB4F                           Team Handed
# 1784  TRUGSQG128F42597B9  It's Only Love That Gets You Through
# 1785  TRTNXLT12903CFF249                   You Always Believed
# 1786  TRINOKE128F427CFDF                       Ruf In Den Wind
# 1787  TRYFJBZ128E0783C26                     Two Way Monologue
# 1788  TRRLOIC12903C9D185                            Depression
# 1789  TRFGOBH128E078EC0C                    '97 Bonnie & Clyde
# 1790  TRPJJUF128F933FE56        Most Things Haven't Worked Out
# 1791  TRDMZLZ12903CBAE4A                              Mornings
# 1792  TRFFFFJ128F4259B34                Inspection (Check One)
# 1793  TRPAQIY128F426272D                Eagles Become Vultures
# 1794  TRORJRP128F9318C80                          I'm Not Here
# 1795  TRBLDQQ128F92E58B4                              Tuolumne
# 1796  TRCCOHD128F148C233          Popular Mechanics for Lovers
# 1797  TRUPZCY128F4270FCC         I Wanted You To Feel The Same
# 1798  TRMKYZN128F93421D3                          Action Woman
# 1799  TRWPDSU128F4230A62                            The Sinner
#
#                  artist                                spotify_preview_url  \
# 1780           9 Lazy 9  https://p.scdn.co/mp3-preview/57dece3b14276088...
# 1781         Boys Noize  https://p.scdn.co/mp3-preview/dbbb8bd5cac6e2c3...
# 1782       Napalm Death  https://p.scdn.co/mp3-preview/74d4e9b9fb3e8549...
# 1783             Mogwai  https://p.scdn.co/mp3-preview/68239957af8339b5...
# 1784               Sade  https://p.scdn.co/mp3-preview/2121408c7bf0a462...
# 1785     In This Moment  https://p.scdn.co/mp3-preview/dc49517e7b2129fb...
# 1786        Equilibrium  https://p.scdn.co/mp3-preview/946067d6434e7a2e...
# 1787      Sondre Lerche  https://p.scdn.co/mp3-preview/8578d08c59a225e2...
# 1788         Black Flag  https://p.scdn.co/mp3-preview/c4a6c19cb6afb96b...
# 1789             Eminem  https://p.scdn.co/mp3-preview/8dafcc8d014faa7a...
# 1790   Junior Kimbrough  https://p.scdn.co/mp3-preview/c868ba9b7d6ff52f...
# 1791  Portugal. The Man  https://p.scdn.co/mp3-preview/a83ae310e770db97...
# 1786  ruf in den wind equilibrium melodic_death_meta...
# 1787  two way monologue sondre lerche alternative, i...
# 1788  depression black flag punk, 80s, hardcore, pun...
# 1789         '97 bonnie & clyde eminem rap, hip_hop rap
# 1790  most things haven't worked out junior kimbroug...
# 1791  mornings portugal. the man rock, alternative, ...
# 1792  inspection (check one) leftfield electronic, h...
# 1793  eagles become vultures converge hardcore, meta...
# 1794  i'm not here meat puppets rock, alternative, p...
# 1795  tuolumne eddie vedder rock, alternative, folk,...
# 1796  popular mechanics for lovers beulah indie, sou...
# 1797  i wanted you to feel the same the radio dept. ...
# 1798  action woman the litter 60s, psychedelic_rock ...
# 1799  the sinner memphis may fire metalcore, post_ha...
#
# [20 rows x 26 columns]

# %%
similar=cosine_similarity(matrix)

# %%
similar.shape
# Out:
# (1800, 1800)

# %%
with open('similarity.pkl', 'wb') as file:
    pickle.dump(similar, file)

# %%
with open('df_sample.pkl', 'wb') as file:
    pickle.dump(df_sample, file)

# %%
# !pip install feather-format

with open('similarity.feather', 'wb') as file:
    pickle.dump(similar, file)
# Out:
# Requirement already satisfied: feather-format in c:\users\ken\anaconda3\lib\site-packages (0.4.1)
# Requirement already satisfied: pyarrow>=0.4.0 in c:\users\ken\anaconda3\lib\site-packages (from feather-format) (12.0.1)
# Requirement already satisfied: numpy>=1.16.6 in c:\users\ken\anaconda3\lib\site-packages (from pyarrow>=0.4.0->feather-format) (1.26.2)
# WARNING: Ignoring invalid distribution -illow (c:\users\ken\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\ken\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\ken\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\ken\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\ken\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\ken\anaconda3\lib\site-packages)

# %%
similar[1]
# Out:
# array([0.        , 1.        , 0.03687528, ..., 0.        , 0.        ,
#        0.        ])

# %%
df_sample[df_sample["name"]=="Eye of the Needle"].index[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[195], line 1
# ----> 1 df_sample[df_sample["name"]=="Eye of the Needle"].index[0]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:5366, in Index.__getitem__(self, key)
#    5363 if is_integer(key) or is_float(key):
#    5364     # GH#44051 exclude bool, which would return a 2d ndarray
#    5365     key = com.cast_scalar_indexer(key)
# -> 5366     return getitem(key)
#    5368 if isinstance(key, slice):
#    5369     # This case is separated from the conditional above to avoid
#    5370     # pessimization com.is_bool_indexer and ndim checks.
#    5371     return self._getitem_slice(key)
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
def recommender(song_name):
    idx=df_sample[df_sample["name"]==song_name].index[0]
    distance=sorted(list(enumerate(similar[idx])),reverse=True,key=lambda x:x[1])
    names=[]
    for s_id in distance[1:21]:
        names.append(df_sample.iloc[s_id[0]]["name"])
        
    return names

# %%
song_name="Eye of the Needle"

# %%
recommender(song_name)
# Out:
# ['The Greatest',
#  'Chandelier',
#  'You Have Been Loved',
#  'Little Black Sandals',
#  'Beautiful Calm Driving',
#  'Poison Eye',
#  'Needle in the Hay',
#  'More Than Meets The Eye',
#  'Story Of The Eye',
#  'Shooting Up In Vain',
#  'Blind Eye Halo',
#  'Pop Art Blue',
#  'Always Too Late',
#  'Few Too Many',
#  'Stay Now',
#  'Poem to a Horse',
#  "I'm Outta Love",
#  'The World Is Not Enough',
#  'Something I Never Had',
#  "Sweet Darlin'"]

# %%
import ipywidgets as widgets
from IPython.display import display

# Function to get song recommendations
def recommender(song_name):
    idx=df_sample[df_sample["name"]==song_name].index[0]
    distance=sorted(list(enumerate(similar[idx])),reverse=True,key=lambda x:x[1])
    names=[]
    for s_id in distance[1:21]:
        names.append(df_sample.iloc[s_id[0]]["name"])
        
    return names

# Create a dropdown widget
song_dropdown = widgets.Dropdown(
    options=music['name'].values,
    value=music['name'].values[0],
    description='Select a song:',
    disabled=False,
)

# Define a function to handle dropdown changes
def on_dropdown_change(change):
    selected_song = change['new']
    recommended_songs = recommender(selected_song)
    print(f"Recommended songs for '{selected_song}': {recommended_songs}")
        # Print a horizontal line separator
    print('-' * 100)


# Attach the function to the dropdown's value attribute
song_dropdown.observe(on_dropdown_change, names='value')

# Display the dropdown widget
display(song_dropdown)
# Out:
# Dropdown(description='Select a song:', options=('Dine Alone', 'Big Mess', 'Electricityscape', '213', 'Today Is…

# %%
import ipywidgets as widgets
from IPython.display import display

# Function to get song recommendations
def recommender(song_name):
    idx=df_sample[df_sample["name"]==song_name].index[0]
    distance=sorted(list(enumerate(similar[idx])),reverse=True,key=lambda x:x[1])
    names=[]
    for s_id in distance[1:21]:
        song = df_sample.iloc[s_id[0]]["name"]
        link = df_sample.iloc[s_id[0]]["spotify_preview_url"]
        names.append((song, link))  
    return names

# Create a dropdown widget
song_dropdown = widgets.Dropdown(
    options=music['name'].values,
    value=music['name'].values[0],
    description='Select a song:',
    disabled=False,
)

# Define a function to handle dropdown changes
def on_dropdown_change(change):
    selected_song = change['new']
    recommended_songs = recommender(selected_song)
    
        # Print the new recommendations with hyperlinks
    print(f"Recommended songs for '{selected_song}':")
    for song, link in recommended_songs:
        display(HTML(f'<a href="{link}" target="_blank">{song}</a>'))
        
        # Print a horizontal line separator
    print('-' * 120)


# Attach the function to the dropdown's value attribute
song_dropdown.observe(on_dropdown_change, names='value')

# Display the dropdown widget
display(song_dropdown)
# Out:
# Dropdown(description='Select a song:', options=('Dine Alone', 'Big Mess', 'Electricityscape', '213', 'Today Is…

# %%
import ipywidgets as widgets
from IPython.display import display, clear_output, HTML

# Function to get song recommendations
def recommender(song_name):
    idx = df_sample[df_sample["name"] == song_name].index[0]
    distance = sorted(list(enumerate(similar[idx])), reverse=True, key=lambda x: x[1])
    recommendations = []
    for s_id in distance[1:21]:
        song = df_sample.iloc[s_id[0]]["name"]
        link = df_sample.iloc[s_id[0]]["spotify_preview_url"]
        recommendations.append((song, link))

    return recommendations

# Create a dropdown widget
song_dropdown = widgets.Dropdown(
    options=df_sample['name'].values,
    value=df_sample['name'].values[0],
    description='Select a song:',
    disabled=False,
)

# Define a function to handle dropdown changes
def on_dropdown_change(change):
    selected_song = change['new']
    recommended_songs = recommender(selected_song)

    # Clear the previous output
    clear_output(wait=True)

    # Print the new recommendations with hyperlinks
    print(f"Recommended songs for '{selected_song}':")
    for song, link in recommended_songs:
        display(HTML(f'<a href="{link}" target="_blank">{song}</a>'))

    # Print a horizontal line separator
    print('-' * 100)

# Attach the function to the dropdown's value attribute
song_dropdown.observe(on_dropdown_change, names='value')

# Display the dropdown widget
display(song_dropdown)

# %%
pip install --upgrade pandas
# Out:
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied
#      --------------------------------------  15.6/15.8 MB 70.8 kB/s eta 0:00:04
#      --------------------------------------  15.6/15.8 MB 70.8 kB/s eta 0:00:04
#      --------------------------------------  15.6/15.8 MB 71.6 kB/s eta 0:00:03
#      --------------------------------------  15.6/15.8 MB 72.2 kB/s eta 0:00:03
#      --------------------------------------  15.6/15.8 MB 72.7 kB/s eta 0:00:03
#      --------------------------------------  15.6/15.8 MB 72.7 kB/s eta 0:00:03
#      --------------------------------------  15.6/15.8 MB 72.7 kB/s eta 0:00:03
#      --------------------------------------  15.7/15.8 MB 72.8 kB/s eta 0:00:02
#      --------------------------------------  15.7/15.8 MB 72.8 kB/s eta 0:00:02
#      --------------------------------------  15.7/15.8 MB 73.2 kB/s eta 0:00:02
#      --------------------------------------  15.7/15.8 MB 73.2 kB/s eta 0:00:02
#      --------------------------------------  15.7/15.8 MB 73.2 kB/s eta 0:00:02
#      --------------------------------------  15.7/15.8 MB 73.2 kB/s eta 0:00:02
#      --------------------------------------  15.7/15.8 MB 73.2 kB/s eta 0:00:02
#      --------------------------------------  15.7/15.8 MB 73.2 kB/s eta 0:00:02
#      --------------------------------------  15.7/15.8 MB 73.2 kB/s eta 0:00:02
#      --------------------------------------  15.7/15.8 MB 73.2 kB/s eta 0:00:02
#      --------------------------------------  15.7/15.8 MB 73.2 kB/s eta 0:00:02
#      --------------------------------------  15.7/15.8 MB 73.2 kB/s eta 0:00:02
#      --------------------------------------  15.7/15.8 MB 73.2 kB/s eta 0:00:02
#      --------------------------------------  15.7/15.8 MB 73.2 kB/s eta 0:00:02
#      --------------------------------------  15.7/15.8 MB 73.2 kB/s eta 0:00:02
#      --------------------------------------  15.7/15.8 MB 73.2 kB/s eta 0:00:02
#      --------------------------------------  15.7/15.8 MB 73.2 kB/s eta 0:00:02
#      --------------------------------------  15.7/15.8 MB 73.2 kB/s eta 0:00:02
#      --------------------------------------  15.7/15.8 MB 73.2 kB/s eta 0:00:02
#      --------------------------------------  15.7/15.8 MB 73.2 kB/s eta 0:00:02
#      --------------------------------------  15.7/15.8 MB 73.2 kB/s eta 0:00:02
#      --------------------------------------  15.7/15.8 MB 73.2 kB/s eta 0:00:02
#      --------------------------------------  15.7/15.8 MB 73.2 kB/s eta 0:00:02
#      --------------------------------------  15.7/15.8 MB 73.2 kB/s eta 0:00:02
#      --------------------------------------  15.7/15.8 MB 73.2 kB/s eta 0:00:02
#      --------------------------------------  15.7/15.8 MB 73.2 kB/s eta 0:00:02
#      --------------------------------------  15.7/15.8 MB 73.2 kB/s eta 0:00:02
#      --------------------------------------  15.7/15.8 MB 73.2 kB/s eta 0:00:02
#      --------------------------------------  15.7/15.8 MB 69.5 kB/s eta 0:00:01
#      --------------------------------------  15.7/15.8 MB 69.5 kB/s eta 0:00:01
#      --------------------------------------  15.7/15.8 MB 69.5 kB/s eta 0:00:01
#      --------------------------------------  15.8/15.8 MB 71.1 kB/s eta 0:00:01
#      --------------------------------------  15.8/15.8 MB 71.1 kB/s eta 0:00:01
#      --------------------------------------  15.8/15.8 MB 71.1 kB/s eta 0:00:01
#      --------------------------------------  15.8/15.8 MB 71.1 kB/s eta 0:00:01
#      --------------------------------------  15.8/15.8 MB 71.1 kB/s eta 0:00:01
#      --------------------------------------  15.8/15.8 MB 71.1 kB/s eta 0:00:01
#      --------------------------------------  15.8/15.8 MB 71.1 kB/s eta 0:00:01
#      --------------------------------------- 15.8/15.8 MB 70.1 kB/s eta 0:00:00
# Requirement already satisfied: pytz>=2020.1 in c:\users\ken\anaconda3\lib\site-packages (from pandas) (2022.7)
# Requirement already satisfied: six>=1.5 in c:\users\ken\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Installing collected packages: numpy, pandas
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.20.2
#     Uninstalling numpy-1.20.2:
#       Successfully uninstalled numpy-1.20.2
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.3.4
#     Uninstalling pandas-1.3.4:
#       Successfully uninstalled pandas-1.3.4

# %%
pickle.dump(similar,open("similarity","wb"))

# %%
pickle.dump(df_sample,open("df_sample","wb"))

# %%
with open('df_sample.pkl', 'wb') as file:
    pickle.dump(df_sample, file, protocol=4)  # Use protocol 4 or lower

# %%
with open('similarity.pkl', 'wb') as file:
    pickle.dump(similarity, file, protocol=4)  # Use protocol 4 or lower

# %%
# Assuming df_sample is your DataFrame
df_sample.to_pickle('df_sample.pkl')

# %%
# Assuming df_sample is your DataFrame
df_sample.to_pickle('similarity.pkl')

# %%
music = pickle.load(open('df_sample.pkl','rb'))
similarity = pickle.load(open('similarity.pkl','rb'))

# %%
print(similarity.index)
print(music.index)
# Out:
# RangeIndex(start=0, stop=10000, step=1)
# RangeIndex(start=0, stop=10000, step=1)

# %%
print(music.shape)
print(similarity.shape)
# Out:
# (10000, 26)
# (10000, 26)

# %%
def recommend(song):
    index = music[music['name'] == song].index[0]
    print("Index:", index)
    distances = sorted(list(enumerate(similarity[index])), reverse=True, key=lambda x: x[1])
    recommended_music_names = []
    recommended_music_posters = []
    for i in distances[1:6]:
        # fetch the movie poster
        artist = music.iloc[i[0]].artist
        print(artist)
        print(music.iloc[i[0]].song)
        recommended_music_posters.append(get_song_album_cover_url(music.iloc[i[0]].song, artist))
        recommended_music_names.append(music.iloc[i[0]].song)

    return recommended_music_names,recommended_music_posters

# %%
df_sample.head()
# Out:
#              track_id              name                     artist  \
# 0  TRYFTMN128F427E2A1            Navajo                 Black Lips
# 1  TRUXWBF128E0785B09    Cheers Darlin'                Damien Rice
# 2  TRQIMNM128F933376E  Speak in Tongues                    Placebo
# 3  TRTRXCY128E07816DE       Song of Joy  Nick Cave & The Bad Seeds
# 4  TRJOFKB128F429594A             Nesso            Vladislav Delay
#
#                                  spotify_preview_url              spotify_id  \
# 0  https://p.scdn.co/mp3-preview/67f201267b840c9f...  3ZyjXmhyg3r7wtz4rcHayS
# 1  https://p.scdn.co/mp3-preview/19e8d7b3875de8bc...  44zGAo63hhc3xo0rlBweRo
# 2  https://p.scdn.co/mp3-preview/8ff3dc53f4913f8b...  0Hh5QbBZJVZhgFXoLxBcYB
# 3  https://p.scdn.co/mp3-preview/1af9c1b6d389651e...  1pjM5AWnBkMRUv8yEBVMrJ
# 4  https://p.scdn.co/mp3-preview/97770968686d3d96...  2WOLkweNzJ7XsSo2GLub7c
#
#                                                 tags       genre  year  \
# 0  rock, alternative_rock, psychedelic, country, ...        Rock  2007
# 1  alternative, indie, folk, indie_rock, singer_s...        Folk  2003
# 2             alternative, alternative_rock, british        Rock  2009
# 3  rock, alternative, alternative_rock, experimen...        Rock  1996
# 4                                            ambient  Electronic  2007
#
#    duration_ms  danceability  ...  instrumentalness  liveness  valence  \
# 0       161026         0.607  ...          0.000002     0.125   0.4680
# 1       350226         0.549  ...          0.000507     0.165   0.1030
# 2       246026         0.654  ...          0.068800     0.105   0.0784
# 3       407293         0.401  ...          0.000747     0.107   0.0900
# 4       191773         0.292  ...          0.492000     0.193   0.3490
#
#      tempo  time_signature  total_playcount_track  average_playcount_track  \
# 0  105.589               4                  889.0                 2.924342
# 1  113.552               3                 5274.0                 2.765600
# 2  140.273               4                  571.0                 2.130597
# 3   82.136               4                  595.0                 1.776119
# 4  137.065               4                   39.0                 2.294118
#
#    max_playcount_track  min_playcount_track  \
# 0                 28.0                  1.0
# 1                 92.0                  1.0
# 2                 18.0                  1.0
# 3                 25.0                  1.0
# 4                  5.0                  1.0
#
#                                        text_features
# 0  navajo black lips rock, alternative_rock, psyc...
# 1  cheers darlin' damien rice alternative, indie,...
# 2  speak in tongues placebo alternative, alternat...
# 3  song of joy nick cave & the bad seeds rock, al...
# 4           nesso vladislav delay ambient electronic
#
# [5 rows x 26 columns]

# %%
df_sample.dtypes
# Out:
# track_id                    object
# name                        object
# artist                      object
# spotify_preview_url         object
# spotify_id                  object
# tags                        object
# genre                       object
# year                         int64
# duration_ms                  int64
# danceability               float64
# energy                     float64
# key                          int64
# loudness                   float64
# mode                         int64
# speechiness                float64
# acousticness               float64
# instrumentalness           float64
# liveness                   float64
# valence                    float64
# tempo                      float64
# time_signature               int64
# total_playcount_track      float64
# average_playcount_track    float64
# max_playcount_track        float64
# min_playcount_track        float64
# text_features               object
# dtype: object

# %%
similarity.dtypes
# Out:
# track_id                    object
# name                        object
# artist                      object
# spotify_preview_url         object
# spotify_id                  object
# tags                        object
# genre                       object
# year                         int64
# duration_ms                  int64
# danceability               float64
# energy                     float64
# key                          int64
# loudness                   float64
# mode                         int64
# speechiness                float64
# acousticness               float64
# instrumentalness           float64
# liveness                   float64
# valence                    float64
# tempo                      float64
# time_signature               int64
# total_playcount_track      float64
# average_playcount_track    float64
# max_playcount_track        float64
# min_playcount_track        float64
# text_features               object
# dtype: object
